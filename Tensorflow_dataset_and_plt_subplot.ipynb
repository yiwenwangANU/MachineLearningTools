# %% [markdown]
# <a href="https://colab.research.google.com/github/yiwenwangANU/MachineLearningTools/blob/main/Tensorflow_dataset_and_plt_subplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
dataset = tf.data.Dataset.from_tensor_slices([1, 2, 3])
dataset
# Out:
# <TensorSliceDataset element_spec=TensorSpec(shape=(), dtype=tf.int32, name=None)>

# %%
for element in dataset:
  print(element)
# Out:
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(2, shape=(), dtype=int32)
# tf.Tensor(3, shape=(), dtype=int32)

# %%
dataset1 = tf.data.Dataset.from_tensor_slices(tf.random.uniform([4, 10]))
dataset1
# Out:
# <TensorSliceDataset element_spec=TensorSpec(shape=(10,), dtype=tf.float32, name=None)>

# %%
tf.random.uniform([4, 10])
# Out:
# <tf.Tensor: shape=(4, 10), dtype=float32, numpy=
# array([[0.3159405 , 0.806461  , 0.61033475, 0.8559663 , 0.301993  ,
#         0.2557577 , 0.01826131, 0.22510481, 0.57969975, 0.2176894 ],
#        [0.13047779, 0.54773724, 0.92743003, 0.0548687 , 0.39065063,
#         0.84890413, 0.7176435 , 0.0831542 , 0.5783112 , 0.5160912 ],
#        [0.5763601 , 0.61028373, 0.23109293, 0.83057415, 0.0285877 ,
#         0.50630355, 0.20035076, 0.48515654, 0.33451724, 0.83910716],
#        [0.02438605, 0.41483045, 0.3205911 , 0.9610226 , 0.41644943,
#         0.02668178, 0.843874  , 0.64713347, 0.21488881, 0.38585126]],
#       dtype=float32)>

# %%
for element in dataset1:
  print(element)
# Out:
# tf.Tensor(
# [0.811067   0.07938552 0.39039302 0.19624317 0.5972599  0.20738304
#  0.52087116 0.7531364  0.55595016 0.02822077], shape=(10,), dtype=float32)
# tf.Tensor(
# [0.60374    0.05053723 0.20148456 0.5037123  0.64784837 0.7345401
#  0.7978736  0.38059723 0.01444685 0.05016899], shape=(10,), dtype=float32)
# tf.Tensor(
# [0.98432064 0.4430802  0.7821679  0.80536556 0.84703207 0.35083556
#  0.5729282  0.4046712  0.4139564  0.2282393 ], shape=(10,), dtype=float32)
# tf.Tensor(
# [0.5356339  0.03306782 0.5038897  0.45447063 0.6787615  0.0048517
#  0.6684687  0.12411702 0.43392837 0.30712163], shape=(10,), dtype=float32)

# %%
dataset2 = tf.data.Dataset.from_tensor_slices(
   (tf.random.uniform([4]),
    tf.random.uniform([4, 100], maxval=100, dtype=tf.int32)))

# %%
dataset2
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(), dtype=tf.float32, name=None), TensorSpec(shape=(100,), dtype=tf.int32, name=None))>

# %%
for element1, element2 in dataset2:
  print(element2)

# %%
st = tf.SparseTensor(indices=[[0, 0], [1, 2]], values=[1, 2], dense_shape=[3, 4])

# %%
dataset4 = tf.data.Dataset.from_tensors(st)
dataset4.element_spec
# Out:
# SparseTensorSpec(TensorShape([3, 4]), tf.int32)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(2, 3, sharex=True, sharey=True)
fig.suptitle("suptitle")
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)),
                      fontsize=18, ha='center')
        ax[i, j].set_title(f"{i},{j}")
#plt.tight_layout()

# %%
import numpy as np

# First create some toy data:
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)

# %%
# Create just a figure and only one subplot
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('Simple plot')
# Out:
# Text(0.5, 1.0, 'Simple plot')

# %%
# Create two subplots and unpack the output array immediately
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(x, y)
ax1.set_title('Sharing Y axis')
ax2.scatter(x, y)

# %%
# Create four polar axes and access them through the returned array
fig, axs = plt.subplots(2, 2, subplot_kw=dict(projection="polar"))
axs[0, 0].plot(x, y)
axs[1, 1].scatter(x, y)

# %%
fig, ax = plt.subplots(num=10, clear=True)

# %%
import tensorflow as tf

train, test = tf.keras.datasets.fashion_mnist.load_data()
# Out:
# ...
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
X, y = train

# %%
dataset = tf.data.Dataset.from_tensor_slices(train)

# %%
y.shape
# Out:
# (60000,)

# %%
import tensorflow as tf
inc_dataset = tf.data.Dataset.range(5)

# %%
inc_dataset.take(1)
# Out:
# <TakeDataset element_spec=TensorSpec(shape=(), dtype=tf.int64, name=None)>

# %%
for element in inc_dataset:
  print(element)
# Out:
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(1, shape=(), dtype=int64)
# tf.Tensor(2, shape=(), dtype=int64)
# tf.Tensor(3, shape=(), dtype=int64)
# tf.Tensor(4, shape=(), dtype=int64)

# %%
it = iter(inc_dataset)
print(next(it).numpy())
print(next(it))
# Out:
# 0
# tf.Tensor(1, shape=(), dtype=int64)

# %%
dataset = tf.data.Dataset.range(10)
dataset = dataset.take(3)
list(dataset.as_numpy_iterator())
# Out:
# [0, 1, 2]

# %%
dataset
# Out:
# <TakeDataset element_spec=TensorSpec(shape=(), dtype=tf.int64, name=None)>

# %%
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')
# Out:
# WARNING:tensorflow:Mixed precision compatibility check (mixed_float16): WARNING
# The dtype policy mixed_float16 may run slowly because this machine does not have a GPU. Only Nvidia GPUs with compute capability of at least 7.0 run quickly with mixed_float16.
# If you will use compatible GPU(s) not attached to this host, e.g. by running a multi-worker model, you can ignore this warning. This message will only be logged once
